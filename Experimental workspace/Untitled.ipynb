# %%
import pandas as pd

# %%
df = pd.read_csv("ed_public_dataset.csv")

# %%
df.head()
# Out:
#     oshpd_id     FacilityName2 CountyName                 system  \
# 0  106010735  Alameda Hospital    Alameda  Alameda Health System
# 1  106010735  Alameda Hospital    Alameda  Alameda Health System
# 2  106010735  Alameda Hospital    Alameda  Alameda Health System
# 3  106010735  Alameda Hospital    Alameda  Alameda Health System
# 4  106010735  Alameda Hospital    Alameda  Alameda Health System
#
#   LICENSED_BED_SIZE HospitalOwnership UrbanRuralDesi TEACHINGDesignation  \
# 0           100-149        Government          Urban        Non-Teaching
# 1           100-149        Government          Urban        Non-Teaching
# 2           100-149        Government          Urban        Non-Teaching
# 3           100-149        Government          Urban        Non-Teaching
# 4           100-149        Government          Urban        Non-Teaching
#
#            Category  Tot_ED_NmbVsts  EDStations  EDDXCount  LATITUDE  \
# ...
